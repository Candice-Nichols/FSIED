# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
resolutions = [5, 10, 15, 20]
refprot = 810.3
protdensity = [699.9, 851.2, 947.8, 968.3]
refhem = 82.9
hemdensity = [51.2, 85, 101, 118]
refmcm = 1240.9
mcmdensity = [1306.7, 1684.6, 2009.9, 2121.4]
refrub = 733.7
rubdensity = [766.2, 1004.0, 1113.7, 1173.1]
refrna = 752.8
rnadensity = [899.5, 1110.1, 1282.4, 1401.4]

protdiff = [x-refprot for x in protdensity]
hemdiff = [x-refhem for x in hemdensity]
mcmdiff = [x-refmcm for x in mcmdensity]
rubdiff = [x-refrub for x in rubdensity]
rnadiff = [x-refrna for x in rnadensity]

df = pd.DataFrame({'Resolution': resolutions,'Proteasome (EMDBID: 2981)': protdiff, 'Hemoglobin (EMDBID: 3488)': hemdiff,'MCM (EMDBID: 9400)': mcmdiff, 'Rubisco (EMDBID: 3699)' : rubdiff, 'Rna polymerase (EMDBID: 3957)': rnadiff})

# %%
df = df.set_index('Resolution')

# %%
df
# Out:
#             Proteasome (EMDBID: 2981)  Hemoglobin (EMDBID: 3488)  \
# Resolution
# 5                              -110.4                      -31.7
# 10                               40.9                        2.1
# 15                              137.5                       18.1
# 20                              158.0                       35.1
#
#             MCM (EMDBID: 9400)  Rubisco (EMDBID: 3699)  \
# Resolution
# 5                         65.8                    32.5
# 10                       443.7                   270.3
# 15                       769.0                   380.0
# 20                       880.5                   439.4
#
#             Rna polymerase (EMDBID: 3957)
# Resolution
# 5                                   146.7
# 10                                  357.3
# 15                                  529.5
# 20                                  648.6

# %%
#adding dash styles 
dash_styles = ["",
               (4, 1.5),
               (1, 1),
               (3, 1, 1.5, 1),
               (4, 1, 5, 4)
                ]
sns.set(font_scale=1.5)
plt.figure(figsize=(12,8))

ax = sns.lineplot(data=df, dashes=dash_styles)
plt.show()

# %%
resolutions = [5, 10, 15, 20]

refhem = 82.9
hemdensity = [51.2, 85, 101, 118]
refpdc = 1997.5
pdcdensity = [1490.6, 2045.8, 2375.5, 2510.9]
refsti = 89.6
stidensity = [194.0, 213.6, 252.1, 265.5]
refgprot = 162.4
gprotdensity = [389.0, 390.7, 463.9, 493.3]
refcyto = 282.7
cytodensity = [441.8, 716.4, 672.0, 734.6]
refphos = 271.9
phosdensity = [245.9, 335.9, 381.1, 417.2]
refdna = 168.9
dnadensity = [246.0, 269.2, 355.8, 379.4]
reftfiih = 470.8
tfiihdensity = [543.4, 669.0, 758.2, 804.0]
refexo = 436.7
exodensity = [431.6, 656.1, 733.6, 820.1]
refferr = 665.6
ferrdensity = [526.2, 828.4, 855.6, 903.6]
refrub = 733.7
rubdensity = [766.2, 1004.0, 1113.7, 1173.1]
refhsp = 758.0
hspdensity = [697.2, 853.6, 1013.5, 1106.8]
refrna = 752.8
rnadensity = [899.5, 1110.1, 1282.4, 1401.4]
refprot = 810.3
protdensity = [699.9, 851.2, 947.8, 968.3]
refmcm = 1240.9
mcmdensity = [1306.7, 1684.6, 2009.9, 2121.4]




hemdiff = [x-refhem for x in hemdensity]
pdcdiff = [x-refpdc for x in pdcdensity]
stidiff = [x-refsti for x in stidensity]
gprotdiff = [x-refgprot for x in gprotdensity]
cytodiff = [x-refcyto for x in cytodensity]
phosdiff = [x-refphos for x in phosdensity]
dnadiff = [x-refdna for x in dnadensity]
tfiihdiff = [x-reftfiih for x in tfiihdensity]
exodiff = [x-refexo for x in exodensity]
ferrdiff = [x-refferr for x in ferrdensity]
rubdiff = [x-refrub for x in rubdensity]
hspdiff = [x-refhsp for x in hspdensity]
rnadiff = [x-refrna for x in rnadensity]
protdiff = [x-refprot for x in protdensity]
mcmdiff = [x-refmcm for x in mcmdensity]


df2 = pd.DataFrame({'Resolution': resolutions,'Hemoglobin (EMDBID: 3488)': hemdiff, 'PDC (EMDBID: 7610)': pdcdiff, 'STING (EMDBID: 0502)':stidiff, 'G Protein (EMDBID: 0339)':gprotdiff, 'Cytochrome C (EMDBID: 6896)':cytodiff, 'Phophodiesterase 6 (EMDBID: 9297)':cytodiff, 'DNA Polymerase (EMDBID: 0379)':dnadiff, 'TFIIH (EMDBID: 0452)':tfiihdiff, 'Exosome (EMDBID: 0128)':exodiff, 'Ferritin (EMDBID: 6830)': ferrdiff, 'Rubisco (EMDBID: 3699)' : rubdiff, 'HSP104 (EMDBID: 7782)':hspdiff , 'Rna polymerase (EMDBID: 3957)' : rnadiff, 'Proteasome (EMDBID: 2981)': protdiff,'MCM (EMDBID: 9400)': mcmdiff})

# %%
df2 = df2.set_index('Resolution')

df2
# Out:
#             Hemoglobin (EMDBID: 3488)  PDC (EMDBID: 7610)  \
# Resolution
# 5                               -31.7              -506.9
# 10                                2.1                48.3
# 15                               18.1               378.0
# 20                               35.1               513.4
#
#             STING (EMDBID: 0502)  G Protein (EMDBID: 0339)  \
# Resolution
# 5                          104.4                     226.6
# 10                         124.0                     228.3
# 15                         162.5                     301.5
# 20                         175.9                     330.9
#
#             Cytochrome C (EMDBID: 6896)  Phophodiesterase 6 (EMDBID: 9297)  \
# Resolution
# 5                                 159.1                              159.1
# 10                                433.7                              433.7
# 15                                389.3                              389.3
# ...

# %%
#adding dash styles 
dash_styles = ["",
               (4, 1.5),
               (1, 1),
               (3, 1, 1.5, 1),
               (4, 1, 5, 4),
               (5, 1, 4, 3),
               (2, 2, 4, 2),
               (8, 1, 4, 2),
               (9, 0, 2, 4),
               (7, 4, 4, 3),
               (8, 4, 4, 1),
               (3, 3, 3, 4),
               (4, 2, 1, 1.5),
               (1.5, 1.5, 2, 3),
               (3, 1.5, 4, 7),
               (4, 2.5, 5, 5)
                ]
sns.set(font_scale=0.8)
plt.figure(figsize=(12,8))

ax = sns.lineplot(data=df2, dashes=dash_styles)
plt.show()
